# %% [markdown]
# # Machine learning and FinTech Hw 1.                                        0616098 黃秉茂

# %% [markdown]
# #### import every module I need

# %%
import pandas as pd 
import numpy as np  
import seaborn as sns
import matplotlib.pyplot as plt
import math   # This will import math module
import matplotlib.font_manager as fm
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 1. For your individual final project, think about the following questions and write down your answers.

# %% [markdown]
# ### a) What is the topic about FinTech you would like to work out? Briefly explain your problem.

# %% [markdown]
# 股票買賣<br>
# 判斷應該是要買多還是賣空、預判漲跌，然後利潤最大化

# %% [markdown]
# ### b) Write down your motivations and explain why this topic is important?

# %% [markdown]
# * 動機：個人利益方面，當然是希望所學能幫自己增加利益。社會方面，因為AI在有些方面已經超越人類了，就像是圍棋，而運用在財金方面是否能有顯著的提供協助?財金相較於其他領域是更貼近人們的生活的，且投資要考量的變數實在很多，所以我很好奇運用AI技術的投資能否打敗人類。
# * 重要性：AI已經有發展到一定的程度了，然而運用AI的領域實在不算多，目前可能只有遊戲、視覺、跟自然語言處理，如果AI加上財金將會大大地改變人們的生活，而且投資並不是只有考量數學，還是一門跟人文、心理相關的學問，而AI是否能連這些都考慮到是我所好奇的。

# %% [markdown]
# ### c) Provide at least one related work (paper or book) about the topic.

# %% [markdown]
# Lee, Tae Kyun, et al. "Global stock market investment strategies based on financial network indicators using machine learning techniques." Expert Systems with Applications 117 (2019): 228-242.<br>
# ["Global stock market investment strategies based on financial network indicators using machine learning techniques](https://www.sciencedirect.com/science/article/pii/S0957417418305761)

# %% [markdown]
# ### d) Formulate your problem as clear as possible.

# %% [markdown]
# * 起始金額為100,000元，希望最後能賺最多錢
# * 每天都要判斷買多還是賣多這固定的十檔股票(0050、0056、台積電、大立光、聯發科、鴻海、玉山金、富邦金、國泰金、元大金)
# * 自變數會用先前的開盤價、最高價、最低價、收盤價、成交量、5日均價、20日均價、網路聲量(如果有學會爬蟲的話)等等，而變數就是這十檔分別該買還是賣
# * 預測哪些會漲那些會跌之後，認為漲的就花10,000元左右去買且隔天賣掉，認為會跌的也是融券約10,000元的額度且隔天買回，隔天都會平倉

# %% [markdown]
# ### e) Find the data you would like to use. Write down the source of your data, summarize the data set information and attribution information. Provide the exploratory data analysis (EDA) for your data.

# %% [markdown]
# data source: yahoo finance, TEJ, apple stock<br>
# 會先將.csv下載下來後，再使用pandas, numpy等進行EDA

# %%
stock_data = pd.read_csv('stock.csv',encoding='utf-8')
print("dataset_shape = ", stock_data.shape)
# Out:
# dataset_shape =  (14020, 29)

# %%
stock_data.head()
# Out:
#           公司代碼       年月日  成份股 開盤價(元) 最高價(元) 最低價(元) 收盤價(元) 成交量(千股)    成交值(千元)  \
# 0  0050 元大台灣50  2015/1/5  NaN   66.4  66.75     66  66.55   6,295    417,637
# 1   0056 元大高股息  2015/1/5  NaN  24.16  24.16  24.01  24.15     508     12,264
# 2     2330 台積電  2015/1/5  NaN  140.5  140.5  137.5  139.5  32,214  4,459,516
# 3     3008 大立光  2015/1/5  NaN  2,400  2,410  2,350  2,350     833  1,979,137
# 4     2454 聯發科  2015/1/5  NaN    460    467    460    462   2,482  1,148,998
#
#     當日均價(元)  ... 現金股利率 股價漲跌(元)   高低價差%  指數因子  累計營收(千元) 單月營收與上月比％ 單月營收成長率％  \
# 0   66.3379  ...  2.33   -0.30  1.1219   NaN       NaN       NaN      NaN
# 1   24.1082  ...  4.14   -0.01  0.6209   NaN       NaN       NaN      NaN
# 2  138.4333  ...  2.15   -1.50  2.1277   NaN       NaN       NaN      NaN
# 3  2,373.52  ...  1.21  -45.00  2.5052   NaN       NaN       NaN      NaN
# 4  462.9097  ...  3.25    0.00  1.5152   NaN       NaN       NaN      NaN
#
#    單月營收(千元)  配股(Y/N)  息值(元)
# 0       NaN      NaN    NaN
# 1       NaN      NaN    NaN
# 2       NaN      NaN    NaN
# 3       NaN      NaN    NaN
# 4       NaN      NaN    NaN
#
# [5 rows x 29 columns]

# %%
print("is_any_null ", stock_data.isnull().values.any())
# Out:
# is_any_null  True

# %%
stock_data.dropna(thresh=len(stock_data.index) / 2, axis=1)
#stock_data = stock_data.dropna(axis=1)
# Out:
#               公司代碼        年月日 開盤價(元) 最高價(元) 最低價(元) 收盤價(元) 成交量(千股)    成交值(千元)  \
# 0      0050 元大台灣50   2015/1/5   66.4  66.75     66  66.55   6,295    417,637
# 1       0056 元大高股息   2015/1/5  24.16  24.16  24.01  24.15     508     12,264
# 2         2330 台積電   2015/1/5  140.5  140.5  137.5  139.5  32,214  4,459,516
# 3         3008 大立光   2015/1/5  2,400  2,410  2,350  2,350     833  1,979,137
# 4         2454 聯發科   2015/1/5    460    467    460    462   2,482  1,148,998
# ...            ...        ...    ...    ...    ...    ...     ...        ...
# 14015      2317 鴻海  2020/9/25   75.4   75.7   74.1   74.3  38,124  2,845,940
# 14016     2884 玉山金  2020/9/25  24.95   25.6  24.95   25.3  28,548    723,566
# 14017     2881 富邦金  2020/9/25   40.6     41   40.6   40.8  12,935    528,488
# 14018     2882 國泰金  2020/9/25  38.05  38.35     38   38.1  12,900    491,726
# 14019     2885 元大金  2020/9/25  17.25   17.6   17.2   17.3  26,052    451,970
#
#         當日均價(元)   5日均價(元)  ...  20日均價(元)    報酬率％  日報酬率 %  流通在外股數(千股)  \
# 0       66.3379   55.8106  ...   54.9418 -0.4488 -0.4488   1,135,500
# 1       24.1082     18.66  ...     18.46 -0.0414 -0.0414     191,534
# 2      138.4333  115.1339  ...  112.7079 -1.0638 -1.0638  25,929,662
# 3      2,373.52  2,183.32  ...  2,130.23 -1.8789 -1.8789     134,140
# 4      462.9097    377.81  ...    367.52  0.0000  0.0000   1,571,492
# ...         ...       ...  ...       ...     ...     ...         ...
# 14015   74.6479     76.04  ...     77.46 -0.9333 -0.9333  13,862,990
# 14016   25.3453     25.48  ...     26.42  1.6064  1.6064  12,567,100
# 14017    40.855     41.49  ...     42.57  0.4926  0.4926  10,233,603
# 14018    38.118     38.64  ...    39.465  0.2632  0.2632  13,169,210
# 14019   17.3485     17.58  ...    18.115  0.8746  0.8746  12,137,435
#
#          市值(百萬元)  本益比-TEJ  股價淨值比-TEJ   現金股利率  股價漲跌(元)   高低價差%
# 0         75,567      NaN        NaN  2.3300    -0.30  1.1219
# 1          4,625      NaN        NaN  4.1400    -0.01  0.6209
# 2      3,617,187  15.9500     3.7800  2.1500    -1.50  2.1277
# 3        315,229  20.5600     8.1500  1.2100   -45.00  2.5052
# 4        726,029  16.4300     3.1400  3.2500     0.00  1.5152
# ...          ...      ...        ...     ...      ...     ...
# 14015  1,030,020  10.6779     0.8497  5.6528    -0.70  2.1333
# 14016    317,947  16.4019     1.7994  2.8910     0.40  2.6104
# 14017    417,531   6.0548     0.8295  4.9020     0.20  0.9852
# 14018    501,746   6.8889     0.7609  5.2493     0.10  0.9211
# 14019    209,977  10.9884     0.9170  3.6127     0.15  2.3324
#
# [14020 rows x 21 columns]

# %%
stock_data.head()
# Out:
#           公司代碼       年月日  成份股 開盤價(元) 最高價(元) 最低價(元) 收盤價(元) 成交量(千股)    成交值(千元)  \
# 0  0050 元大台灣50  2015/1/5  NaN   66.4  66.75     66  66.55   6,295    417,637
# 1   0056 元大高股息  2015/1/5  NaN  24.16  24.16  24.01  24.15     508     12,264
# 2     2330 台積電  2015/1/5  NaN  140.5  140.5  137.5  139.5  32,214  4,459,516
# 3     3008 大立光  2015/1/5  NaN  2,400  2,410  2,350  2,350     833  1,979,137
# 4     2454 聯發科  2015/1/5  NaN    460    467    460    462   2,482  1,148,998
#
#     當日均價(元)  ... 現金股利率 股價漲跌(元)   高低價差%  指數因子  累計營收(千元) 單月營收與上月比％ 單月營收成長率％  \
# 0   66.3379  ...  2.33   -0.30  1.1219   NaN       NaN       NaN      NaN
# 1   24.1082  ...  4.14   -0.01  0.6209   NaN       NaN       NaN      NaN
# 2  138.4333  ...  2.15   -1.50  2.1277   NaN       NaN       NaN      NaN
# 3  2,373.52  ...  1.21  -45.00  2.5052   NaN       NaN       NaN      NaN
# 4  462.9097  ...  3.25    0.00  1.5152   NaN       NaN       NaN      NaN
#
#    單月營收(千元)  配股(Y/N)  息值(元)
# 0       NaN      NaN    NaN
# 1       NaN      NaN    NaN
# 2       NaN      NaN    NaN
# 3       NaN      NaN    NaN
# 4       NaN      NaN    NaN
#
# [5 rows x 29 columns]

# %%
stock_data.tail()
# Out:
#            公司代碼        年月日  成份股 開盤價(元) 最高價(元) 最低價(元) 收盤價(元) 成交量(千股)  \
# 14015   2317 鴻海  2020/9/25  NaN   75.4   75.7   74.1   74.3  38,124
# 14016  2884 玉山金  2020/9/25  NaN  24.95   25.6  24.95   25.3  28,548
# 14017  2881 富邦金  2020/9/25  NaN   40.6     41   40.6   40.8  12,935
# 14018  2882 國泰金  2020/9/25  NaN  38.05  38.35     38   38.1  12,900
# 14019  2885 元大金  2020/9/25  NaN  17.25   17.6   17.2   17.3  26,052
#
#          成交值(千元)  當日均價(元)  ...   現金股利率 股價漲跌(元)   高低價差%  指數因子  累計營收(千元)  \
# 14015  2,845,940  74.6479  ...  5.6528   -0.70  2.1333   NaN       NaN
# 14016    723,566  25.3453  ...  2.8910    0.40  2.6104   NaN       NaN
# 14017    528,488   40.855  ...  4.9020    0.20  0.9852   NaN       NaN
# 14018    491,726   38.118  ...  5.2493    0.10  0.9211   NaN       NaN
# 14019    451,970  17.3485  ...  3.6127    0.15  2.3324   NaN       NaN
#
#       單月營收與上月比％ 單月營收成長率％  單月營收(千元)  配股(Y/N)  息值(元)
# 14015       NaN      NaN       NaN      NaN    NaN
# 14016       NaN      NaN       NaN      NaN    NaN
# 14017       NaN      NaN       NaN      NaN    NaN
# 14018       NaN      NaN       NaN      NaN    NaN
# 14019       NaN      NaN       NaN      NaN    NaN
#
# [5 rows x 29 columns]

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14020 entries, 0 to 14019
# Data columns (total 29 columns):
# 公司代碼          14020 non-null object
# 年月日           14020 non-null object
# 成份股           67 non-null object
# 開盤價(元)        14020 non-null object
# 最高價(元)        14020 non-null object
# 最低價(元)        14020 non-null object
# 收盤價(元)        14020 non-null object
# 成交量(千股)       14020 non-null object
# 成交值(千元)       14020 non-null object
# 當日均價(元)       14012 non-null object
# 5日均價(元)       14020 non-null object
# 10日均價(元)      14020 non-null object
# 20日均價(元)      14020 non-null object
# 報酬率％          14020 non-null float64
# 日報酬率 %        14020 non-null float64
# 流通在外股數(千股)    14020 non-null object
# 市值(百萬元)       14020 non-null object
# 本益比-TEJ       11216 non-null float64
# 股價淨值比-TEJ     11216 non-null float64
# 現金股利率         14020 non-null float64
# 股價漲跌(元)       14020 non-null float64
# 高低價差%         13508 non-null float64
# 指數因子          0 non-null float64
# 累計營收(千元)      544 non-null object
# 單月營收與上月比％     544 non-null float64
# 單月營收成長率％      544 non-null float64
# 單月營收(千元)      544 non-null object
# 配股(Y/N)       68 non-null object
# 息值(元)         67 non-null float64
# dtypes: float64(11), object(18)
# memory usage: 3.1+ MB

# %%
stock_data.describe()
# Out:
#                報酬率％        日報酬率 %       本益比-TEJ     股價淨值比-TEJ         現金股利率  \
# count  14020.000000  14020.000000  11216.000000  11216.000000  14020.000000
# mean       0.046360      0.046360     15.044964      2.296988      3.663234
# std        1.617399      1.617399      7.108142      2.062820      1.391331
# min      -10.000000    -10.000000      5.530000      0.590000      0.000000
# 25%       -0.662300     -0.662300     10.169900      1.020000      2.654900
# 50%        0.000000      0.000000     12.669850      1.400000      3.590000
# 75%        0.732825      0.732825     17.227600      3.120000      4.540000
# max       10.000000     10.000000     47.550000     12.200000     11.000000
#
#             股價漲跌(元)         高低價差%  指數因子   單月營收與上月比％    單月營收成長率％      息值(元)
# count  14020.000000  13508.000000   0.0  544.000000  544.000000  67.000000
# mean       0.139675      1.391597   NaN    4.765239   11.012261   8.821682
# std       32.966458      1.257259   NaN   41.768909   31.401928  18.670174
# min     -465.000000      0.000000   NaN  -81.800000  -69.500000   0.360995
# 25%       -0.350000      0.630300   NaN  -10.310000   -4.285000   0.925000
# 50%        0.000000      1.145000   NaN    0.970000    7.200000   2.000000
# 75%        0.400000      1.841250   NaN   12.210000   21.112500   4.499937
# max      390.000000     12.797600   NaN  705.330000  423.770000  79.000000

# %%
print(stock_data.nunique())
# Out:
# 公司代碼             10
# 年月日            1402
# 成份股              19
# 開盤價(元)         3224
# 最高價(元)         3246
# 最低價(元)         3280
# 收盤價(元)         3289
# 成交量(千股)       11507
# 成交值(千元)       13970
# 當日均價(元)       13927
# 5日均價(元)        9548
# 10日均價(元)      10326
# 20日均價(元)      10696
# 報酬率％           8062
# 日報酬率 %         8062
# 流通在外股數(千股)     1198
# 市值(百萬元)        6911
# 本益比-TEJ        3976
# 股價淨值比-TEJ      2793
# 現金股利率          3323
# 股價漲跌(元)         476
# 高低價差%          6098
# 指數因子              0
# 累計營收(千元)        544
# 單月營收與上月比％       528
# 單月營收成長率％        527
# 單月營收(千元)        544
# 配股(Y/N)           2
# 息值(元)            46
# dtype: int64

# %%
stock_data_cols = stock_data.columns
stock_data_cols_set = set(stock_data_cols)
stock_data_cols_list = list(stock_data_cols_set)
stock_data_continuous_variables_cols = stock_data._get_numeric_data().columns
stock_data_continuous_variables_cols_set = set(stock_data_continuous_variables_cols)
stock_data_continuous_variables_cols_list = list(stock_data_continuous_variables_cols_set)
print("stock_data_continuous_variables: ", stock_data_continuous_variables_cols_list)
stock_data_categorical_variables_cols_set = stock_data_cols_set - stock_data_continuous_variables_cols_set
stock_data_categorical_variables_cols_list = list(stock_data_categorical_variables_cols_set)
print("stock_data_categorical_variables:", stock_data_categorical_variables_cols_list)
# Out:
# stock_data_continuous_variables:  ['報酬率％', '本益比-TEJ', '指數因子', '單月營收成長率％', '日報酬率 %', '股價漲跌(元)', '息值(元)', '現金股利率', '高低價差%', '股價淨值比-TEJ', '單月營收與上月比％']
# stock_data_categorical_variables: ['累計營收(千元)', '成交量(千股)', '20日均價(元)', '配股(Y/N)', '開盤價(元)', '市值(百萬元)', '收盤價(元)', '10日均價(元)', '最低價(元)', '當日均價(元)', '年月日', '單月營收(千元)', '成交值(千元)', '公司代碼', '成份股', '最高價(元)', '流通在外股數(千股)', '5日均價(元)']

# %% [markdown]
# #### frequency tables

# %%
[print(f'categorical variable: {i}\n{stock_data[i].value_counts()}\n') for i in stock_data_categorical_variables_cols_list]
# Out:
# categorical variable: 累計營收(千元)
# 22,905,555     1
# 55,583,411     1
# 53,127,505     1
# 310,597,183    1
# 957,874,271    1
#               ..
# 21,745,414     1
# 130,559,210    1
# 203,495,361    1
# 34,153,975     1
# 224,132,402    1
# Name: 累計營收(千元), Length: 544, dtype: int64
#
# categorical variable: 成交量(千股)
# 513       8
# 0         8
# 700       7
# 713       7
# 773       7
#          ..
# 10,403    1
# 35,603    1
# 24,244    1
# 59,870    1
# 16,390    1
# Name: 成交量(千股), Length: 11507, dtype: int64
#
# categorical variable: 20日均價(元)
# 10.24       11
# 12.55       11
# 19.9        10
# 22.78       10
# 11.5         9
#             ..
# 4,372        1
# 3,287.91     1
# 4,541.24     1
# 76.0627      1
# 116.5043     1
# Name: 20日均價(元), Length: 10696, dtype: int64
#
# categorical variable: 配股(Y/N)
# N    58
# Y    10
# Name: 配股(Y/N), dtype: int64
#
# categorical variable: 開盤價(元)
# 18.4     42
# 18.3     41
# 18.25    39
# 18.5     34
# 13       32
#          ..
# 80.55     1
# 4,460     1
# 4,595     1
# 21.81     1
# 4,065     1
# Name: 開盤價(元), Length: 3224, dtype: int64
#
# categorical variable: 市值(百萬元)
# 155,982    26
# 514,750    22
# 154,782    21
# 513,726    20
# 521,913    20
#            ..
# 167,637     1
# 8,226       1
# 69,223      1
# 19,662      1
# 366,178     1
# Name: 市值(百萬元), Length: 6911, dtype: int64
#
# categorical variable: 收盤價(元)
# 18.3     45
# 18.4     36
# 13       34
# 18.25    33
# 18.45    32
#          ..
# 1,960     1
# 23.33     1
# 5,595     1
# 23.22     1
# 428       1
# Name: 收盤價(元), Length: 3289, dtype: int64
#
# categorical variable: 10日均價(元)
# 17.9        10
# 43.34       10
# 12.52        9
# 42.66        9
# 19.9         9
#             ..
# 3,292.43     1
# 237.74       1
# 4,479.50     1
# 43.785       1
# 116.5043     1
# Name: 10日均價(元), Length: 10326, dtype: int64
#
# categorical variable: 最低價(元)
# 18.3     39
# 18.2     37
# 12.8     36
# 18.25    35
# 18.4     33
#          ..
# 57.5      1
# 29.15     1
# 79.65     1
# 3,295     1
# 20.57     1
# Name: 最低價(元), Length: 3280, dtype: int64
#
# categorical variable: 當日均價(元)
# 27.2012     2
# 82.8462     2
# 27.9046     2
# 51.2872     2
# 18.4544     2
#            ..
# 321.4313    1
# 84.3223     1
# 332.3124    1
# 74.03       1
# 316.6804    1
# Name: 當日均價(元), Length: 13927, dtype: int64
#
# categorical variable: 年月日
# 2018/2/21    10
# 2015/1/9     10
# 2016/8/1     10
# 2015/9/24    10
# 2015/2/3     10
#              ..
# 2020/5/4     10
# 2020/8/13    10
# 2015/4/30    10
# 2019/5/31    10
# 2017/4/7     10
# Name: 年月日, Length: 1402, dtype: int64
#
# categorical variable: 單月營收(千元)
# 85,867,929     1
# 3,968,722      1
# 50,076,418     1
# 449,639,072    1
# 341,690,438    1
#               ..
# 3,918,140      1
# 40,094,569     1
# 27,248,276     1
# 3,104,880      1
# 7,961,004      1
# Name: 單月營收(千元), Length: 544, dtype: int64
#
# categorical variable: 成交值(千元)
# 0            8
# 371,598      2
# 309,390      2
# 291,955      2
# 337,471      2
#             ..
# 2,389,878    1
# 566,506      1
# 1,494,791    1
# 4,584,189    1
# 1,970,743    1
# Name: 成交值(千元), Length: 13970, dtype: int64
#
# categorical variable: 公司代碼
# 2885 元大金       1402
# 2330 台積電       1402
# 2317 鴻海        1402
# 2454 聯發科       1402
# 0056 元大高股息     1402
# 3008 大立光       1402
# 2884 玉山金       1402
# 0050 元大台灣50    1402
# 2881 富邦金       1402
# 2882 國泰金       1402
# Name: 公司代碼, dtype: int64
#
# categorical variable: 成份股
# 2019/12/31    9
# 2016/12/31    9
# 2017/12/31    9
# 2018/12/31    9
# 2015/12/31    8
# 2014/12/31    8
# 2019/6/30     2
# 2015/10/26    2
# 2018/10/23    1
# 2020/3/31     1
# 2019/3/31     1
# 2019/9/30     1
# 2017/10/30    1
# 2020/6/30     1
# 2019/10/23    1
# 2018/6/30     1
# 2016/10/26    1
# 2016/6/30     1
# 2017/6/30     1
# Name: 成份股, dtype: int64
#
# categorical variable: 最高價(元)
# 18.4     41
# 18.3     41
# 18.7     40
# 18.45    39
# 51       34
#          ..
# 5,680     1
# 22.56     1
# 5,875     1
# 22.63     1
# 472       1
# Name: 最高價(元), Length: 3246, dtype: int64
#
# categorical variable: 流通在外股數(千股)
# 10,233,603    1402
# 134,140       1402
# 25,930,380    1328
# 12,563,210    1166
# 17,328,738     528
#               ...
# 1,118,034        1
# 1,893,034        1
# 1,122,500        1
# 1,513,500        1
# 314,534          1
# Name: 流通在外股數(千股), Length: 1198, dtype: int64
#
# categorical variable: 5日均價(元)
# 19.89      11
# 12.5       10
# 19.86       9
# 11.65       8
# 43.36       8
#            ..
# 29.944      1
# 15.2245     1
# 13.6129     1
# 18.3449     1
# 69.58       1
# Name: 5日均價(元), Length: 9548, dtype: int64
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# #### relative frequency tables

# %%
[print(f'categorical variable: {i}\n{stock_data[i].value_counts(normalize=True, sort=True)}\n') for i in stock_data_categorical_variables_cols_list]
# Out:
# categorical variable: 累計營收(千元)
# 22,905,555     0.001838
# 55,583,411     0.001838
# 53,127,505     0.001838
# 310,597,183    0.001838
# 957,874,271    0.001838
#                  ...
# 21,745,414     0.001838
# 130,559,210    0.001838
# 203,495,361    0.001838
# 34,153,975     0.001838
# 224,132,402    0.001838
# Name: 累計營收(千元), Length: 544, dtype: float64
#
# categorical variable: 成交量(千股)
# 513       0.000571
# 0         0.000571
# 700       0.000499
# 713       0.000499
# 773       0.000499
#             ...
# 10,403    0.000071
# 35,603    0.000071
# 24,244    0.000071
# 59,870    0.000071
# 16,390    0.000071
# Name: 成交量(千股), Length: 11507, dtype: float64
#
# categorical variable: 20日均價(元)
# 10.24       0.000785
# 12.55       0.000785
# 19.9        0.000713
# 22.78       0.000713
# 11.5        0.000642
#               ...
# 4,372       0.000071
# 3,287.91    0.000071
# 4,541.24    0.000071
# 76.0627     0.000071
# 116.5043    0.000071
# Name: 20日均價(元), Length: 10696, dtype: float64
#
# categorical variable: 配股(Y/N)
# N    0.852941
# Y    0.147059
# Name: 配股(Y/N), dtype: float64
#
# categorical variable: 開盤價(元)
# 18.4     0.002996
# 18.3     0.002924
# 18.25    0.002782
# 18.5     0.002425
# 13       0.002282
#            ...
# 80.55    0.000071
# 4,460    0.000071
# 4,595    0.000071
# 21.81    0.000071
# 4,065    0.000071
# Name: 開盤價(元), Length: 3224, dtype: float64
#
# categorical variable: 市值(百萬元)
# 155,982    0.001854
# 514,750    0.001569
# 154,782    0.001498
# 513,726    0.001427
# 521,913    0.001427
#              ...
# 167,637    0.000071
# 8,226      0.000071
# 69,223     0.000071
# 19,662     0.000071
# 366,178    0.000071
# Name: 市值(百萬元), Length: 6911, dtype: float64
#
# categorical variable: 收盤價(元)
# 18.3     0.003210
# 18.4     0.002568
# 13       0.002425
# 18.25    0.002354
# 18.45    0.002282
#            ...
# 1,960    0.000071
# 23.33    0.000071
# 5,595    0.000071
# 23.22    0.000071
# 428      0.000071
# Name: 收盤價(元), Length: 3289, dtype: float64
#
# categorical variable: 10日均價(元)
# 17.9        0.000713
# 43.34       0.000713
# 12.52       0.000642
# 42.66       0.000642
# 19.9        0.000642
#               ...
# 3,292.43    0.000071
# 237.74      0.000071
# 4,479.50    0.000071
# 43.785      0.000071
# 116.5043    0.000071
# Name: 10日均價(元), Length: 10326, dtype: float64
#
# categorical variable: 最低價(元)
# 18.3     0.002782
# 18.2     0.002639
# 12.8     0.002568
# 18.25    0.002496
# 18.4     0.002354
#            ...
# 57.5     0.000071
# 29.15    0.000071
# 79.65    0.000071
# 3,295    0.000071
# 20.57    0.000071
# Name: 最低價(元), Length: 3280, dtype: float64
#
# categorical variable: 當日均價(元)
# 27.2012     0.000143
# 82.8462     0.000143
# 27.9046     0.000143
# 51.2872     0.000143
# 18.4544     0.000143
#               ...
# 321.4313    0.000071
# 84.3223     0.000071
# 332.3124    0.000071
# 74.03       0.000071
# 316.6804    0.000071
# Name: 當日均價(元), Length: 13927, dtype: float64
#
# categorical variable: 年月日
# 2018/2/21    0.000713
# 2015/1/9     0.000713
# 2016/8/1     0.000713
# 2015/9/24    0.000713
# 2015/2/3     0.000713
#                ...
# 2020/5/4     0.000713
# 2020/8/13    0.000713
# 2015/4/30    0.000713
# 2019/5/31    0.000713
# 2017/4/7     0.000713
# Name: 年月日, Length: 1402, dtype: float64
#
# categorical variable: 單月營收(千元)
# 85,867,929     0.001838
# 3,968,722      0.001838
# 50,076,418     0.001838
# 449,639,072    0.001838
# 341,690,438    0.001838
#                  ...
# 3,918,140      0.001838
# 40,094,569     0.001838
# 27,248,276     0.001838
# 3,104,880      0.001838
# 7,961,004      0.001838
# Name: 單月營收(千元), Length: 544, dtype: float64
#
# categorical variable: 成交值(千元)
# 0            0.000571
# 371,598      0.000143
# 309,390      0.000143
# 291,955      0.000143
# 337,471      0.000143
#                ...
# 2,389,878    0.000071
# 566,506      0.000071
# 1,494,791    0.000071
# 4,584,189    0.000071
# 1,970,743    0.000071
# Name: 成交值(千元), Length: 13970, dtype: float64
#
# categorical variable: 公司代碼
# 2885 元大金       0.1
# 2330 台積電       0.1
# 2317 鴻海        0.1
# 2454 聯發科       0.1
# 0056 元大高股息     0.1
# 3008 大立光       0.1
# 2884 玉山金       0.1
# 0050 元大台灣50    0.1
# 2881 富邦金       0.1
# 2882 國泰金       0.1
# Name: 公司代碼, dtype: float64
#
# categorical variable: 成份股
# 2019/12/31    0.134328
# 2016/12/31    0.134328
# 2017/12/31    0.134328
# 2018/12/31    0.134328
# 2015/12/31    0.119403
# 2014/12/31    0.119403
# 2019/6/30     0.029851
# 2015/10/26    0.029851
# 2018/10/23    0.014925
# 2020/3/31     0.014925
# 2019/3/31     0.014925
# 2019/9/30     0.014925
# 2017/10/30    0.014925
# 2020/6/30     0.014925
# 2019/10/23    0.014925
# 2018/6/30     0.014925
# 2016/10/26    0.014925
# 2016/6/30     0.014925
# 2017/6/30     0.014925
# Name: 成份股, dtype: float64
#
# categorical variable: 最高價(元)
# 18.4     0.002924
# 18.3     0.002924
# 18.7     0.002853
# 18.45    0.002782
# 51       0.002425
#            ...
# 5,680    0.000071
# 22.56    0.000071
# 5,875    0.000071
# 22.63    0.000071
# 472      0.000071
# Name: 最高價(元), Length: 3246, dtype: float64
#
# categorical variable: 流通在外股數(千股)
# 10,233,603    0.100000
# 134,140       0.100000
# 25,930,380    0.094722
# 12,563,210    0.083167
# 17,328,738    0.037660
#                 ...
# 1,118,034     0.000071
# 1,893,034     0.000071
# 1,122,500     0.000071
# 1,513,500     0.000071
# 314,534       0.000071
# Name: 流通在外股數(千股), Length: 1198, dtype: float64
#
# categorical variable: 5日均價(元)
# 19.89      0.000785
# 12.5       0.000713
# 19.86      0.000642
# 11.65      0.000571
# 43.36      0.000571
#              ...
# 29.944     0.000071
# 15.2245    0.000071
# 13.6129    0.000071
# 18.3449    0.000071
# 69.58      0.000071
# Name: 5日均價(元), Length: 9548, dtype: float64
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# #### bar plots

# %%
# [stock_data[i].value_counts().plot.bar(title=f'Freq dist of {i}') for i in stock_data_categorical_variables_cols_list]
for stock_data_categorical_variables_col in stock_data_categorical_variables_cols_list:
    stock_data[stock_data_categorical_variables_col].value_counts().plot.bar()
#     plt.title(f'Freq dist of {stock_data_categorical_variables_col}')
    # plt.savefig(f'bar{stock_data_categorical_variables_col}.png')
    plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-71bf90366306> in <module>
#       4 #     plt.title(f'Freq dist of {stock_data_categorical_variables_col}')
#       5     # plt.savefig(f'bar{stock_data_categorical_variables_col}.png')
# ----> 6     plt.show()
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# D:\programming\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# D:\programming\Anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# D:\programming\Anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <D:\programming\Anaconda3\lib\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# D:\programming\Anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# D:\programming\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# D:\programming\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# D:\programming\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1203         ticks_to_draw = self._update_ticks()
#    1204         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1205                                                                 renderer)
#    1206
#    1207         for tick in ticks_to_draw:
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1148         """Return lists of bboxes for ticks' label1's and label2's."""
#    1149         return ([tick.label1.get_window_extent(renderer)
# -> 1150                  for tick in ticks if tick.label1.get_visible()],
#    1151                 [tick.label2.get_window_extent(renderer)
#    1152                  for tick in ticks if tick.label2.get_visible()])
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#    1148         """Return lists of bboxes for ticks' label1's and label2's."""
#    1149         return ([tick.label1.get_window_extent(renderer)
# -> 1150                  for tick in ticks if tick.label1.get_visible()],
#    1151                 [tick.label2.get_window_extent(renderer)
#    1152                  for tick in ticks if tick.label2.get_visible()])
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     888             raise RuntimeError('Cannot get window extent w/o renderer')
#     889
# --> 890         bbox, info, descent = self._get_layout(self._renderer)
#     891         x, y = self.get_unitless_position()
#     892         x, y = self.get_transform().transform_point((x, y))
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     336
#     337         # get the rotation matrix
# --> 338         M = Affine2D().rotate_deg(self.get_rotation())
#     339
#     340         # now offset the individual text lines within the box
#
# D:\programming\Anaconda3\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1830         if matrix is None:
#    1831             # A bit faster than np.identity(3).
# -> 1832             matrix = IdentityTransform._mtx.copy()
#    1833         self._mtx = matrix
#    1834         self._invalid = 0
#
# KeyboardInterrupt:

# %% [markdown]
# #### histograms

# %%
for stock_data_continuous_variables_col in stock_data_continuous_variables_cols_list: 
    stock_data[stock_data_continuous_variables_col].hist(figsize= (8, 8), bins= 100)
#     plt.title(stock_data_continuous_variables_col)
    # plt.savefig(f'hist{stock_data_continuous_variables_col}.png')
    plt.show()

# %% [markdown]
# #### distribution plots

# %%
fig, ax = plt.subplots(len(stock_data_stock_data_continuous_variables_cols_list), figsize=(16, 30))
for stock_data_idx, stock_data_continuous_variables_col in enumerate(stock_data_stock_data_continuous_variables_cols_list):
    sns.distplot(stock_data[stock_data_continuous_variables_col], hist=True, ax=ax[stock_data_idx])
    ax[stock_data_idx].set_title('Freq dist '+ stock_data_continuous_variables_col, fontsize=20)
    ax[stock_data_idx].set_xlabel(stock_data_continuous_variables_col, fontsize=10)
    ax[stock_data_idx].set_ylabel('Count', fontsize=10)
plt.show()

# %% [markdown]
# #### pairwise scatterplots

# %%
sns.pairplot(stock_data[stock_data_stock_data_continuous_variables_cols_list])
plt.show()

# %% [markdown]
# #### heatmap

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(stock_data.corr(), annot=False, center=0.0, cmap='coolwarm'); # cmap="YlGnBu",
#plt.savefig('heatmap.png')
plt.show()

# %% [markdown]
# ## 2. Please download the adult dataset and practice how to conduct exploratory data analysis.

# %% [markdown]
# #### read csv in jupyter notebook

# %%
dataset = pd.read_csv('adult.csv')

# %% [markdown]
# #### Viewing/inspecting data

# %%
print("dataset_shape = ", dataset.shape)
# Out:
# dataset_shape =  (32560, 15)

# %%
dataset.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3            Cuba   <=50K
# 4   United-States   <=50K

# %%
dataset.tail()
# Out:
#        39      State-gov   77516    Bachelors   13        Never-married  \
# 32555  27        Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40        Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58        Private  151910      HS-grad    9              Widowed
# 32558  22        Private  201490      HS-grad    9        Never-married
# 32559  52   Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
#              Adm-clerical  Not-in-family   White     Male   2174   0   40  \
# 32555        Tech-support           Wife   White   Female      0   0   38
# 32556   Machine-op-inspct        Husband   White     Male      0   0   40
# 32557        Adm-clerical      Unmarried   White   Female      0   0   40
# 32558        Adm-clerical      Own-child   White     Male      0   0   20
# 32559     Exec-managerial           Wife   White   Female  15024   0   40
#
#         United-States   <=50K
# 32555   United-States   <=50K
# 32556   United-States    >50K
# 32557   United-States   <=50K
# 32558   United-States   <=50K
# 32559   United-States    >50K

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
# 39                32560 non-null int64
#  State-gov        32560 non-null object
#  77516            32560 non-null int64
#  Bachelors        32560 non-null object
#  13               32560 non-null int64
#  Never-married    32560 non-null object
#  Adm-clerical     32560 non-null object
#  Not-in-family    32560 non-null object
#  White            32560 non-null object
#  Male             32560 non-null object
#  2174             32560 non-null int64
#  0                32560 non-null int64
#  40               32560 non-null int64
#  United-States    32560 non-null object
#  <=50K            32560 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# #### data preprocess, add column names

# %%
attribute_name = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'annual-income']

# %%
dataset = pd.read_csv('adult.csv', header=None, names=attribute_name)

# %%
print("dataset_shape = ", dataset.shape)
# Out:
# dataset_shape =  (32561, 15)

# %%
dataset.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country annual-income
# 0          2174             0              40   United-States         <=50K
# 1             0             0              13   United-States         <=50K
# 2             0             0              40   United-States         <=50K
# 3             0             0              40   United-States         <=50K
# 4             0             0              40            Cuba         <=50K

# %%
dataset.tail()
# Out:
#        age      workclass  fnlwgt    education  education-num  \
# 32556   27        Private  257302   Assoc-acdm             12
# 32557   40        Private  154374      HS-grad              9
# 32558   58        Private  151910      HS-grad              9
# 32559   22        Private  201490      HS-grad              9
# 32560   52   Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loss  hours-per-week  native-country  \
# 32556             0             0              38   United-States
# 32557             0             0              40   United-States
# 32558             0             0              40   United-States
# 32559             0             0              20   United-States
# 32560         15024             0              40   United-States
#
#       annual-income
# 32556         <=50K
# 32557          >50K
# 32558         <=50K
# 32559         <=50K
# 32560          >50K

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# annual-income     32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ### 1. Show the summary statistics of all numerical variables.

# %%
dataset.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
print(dataset.nunique())
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education-num        16
# marital-status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital-gain        119
# capital-loss         92
# hours-per-week       94
# native-country       42
# annual-income         2
# dtype: int64

# %% [markdown]
# ### 2. Identify categorical and continuous variables.

# %%
cols = dataset.columns
continuous_variables_cols = dataset._get_numeric_data().columns

# %% [markdown]
# #### continuous variables

# %%
continuous_variables_cols_set = set(continuous_variables_cols)

# %%
continuous_variables_cols_list = list(continuous_variables_cols_set)
print("continuous_variables:", continuous_variables_cols_list)
# Out:
# continuous_variables: ['education-num', 'age', 'capital-gain', 'hours-per-week', 'capital-loss', 'fnlwgt']

# %% [markdown]
# #### categorical variables

# %%
categorical_variables_cols_set = set(cols) - set(continuous_variables_cols)

# %%
categorical_variables_cols_list = list(categorical_variables_cols_set)
print("categorical_variables:", categorical_variables_cols_list)
# Out:
# categorical_variables: ['workclass', 'relationship', 'occupation', 'race', 'marital-status', 'native-country', 'sex', 'annual-income', 'education']

# %% [markdown]
# ### 3. For each categorical variable, print frequency and relative frequency tables.

# %% [markdown]
# #### frequency tables

# %%
[print(f'categorical variable: {i}\n{dataset[i].value_counts()}\n') for i in categorical_variables_cols_list]
# Out:
# categorical variable: workclass
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64
#
# categorical variable: relationship
#  Husband           13193
#  Not-in-family      8305
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: relationship, dtype: int64
#
# categorical variable: occupation
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64
#
# categorical variable: race
#  White                 27816
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: race, dtype: int64
#
# categorical variable: marital-status
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: marital-status, dtype: int64
#
# categorical variable: native-country
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  Greece                           29
#  France                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Trinadad&Tobago                  19
#  Cambodia                         19
#  Laos                             18
#  Thailand                         18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: native-country, dtype: int64
#
# categorical variable: sex
#  Male      21790
#  Female    10771
# Name: sex, dtype: int64
#
# categorical variable: annual-income
#  <=50K    24720
#  >50K      7841
# Name: annual-income, dtype: int64
#
# categorical variable: education
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64
# [None, None, None, None, None, None, None, None, None]

# %% [markdown]
# #### relative frequency tables

# %%
[print(f'categorical variable: {i}\n{dataset[i].value_counts(normalize=True, sort=True)}\n') for i in categorical_variables_cols_list]
# Out:
# categorical variable: workclass
#  Private             0.697030
#  Self-emp-not-inc    0.078038
#  Local-gov           0.064279
#  ?                   0.056386
#  State-gov           0.039864
#  Self-emp-inc        0.034274
#  Federal-gov         0.029483
#  Without-pay         0.000430
#  Never-worked        0.000215
# Name: workclass, dtype: float64
#
# categorical variable: relationship
#  Husband           0.405178
#  Not-in-family     0.255060
#  Own-child         0.155646
#  Unmarried         0.105832
#  Wife              0.048156
#  Other-relative    0.030128
# Name: relationship, dtype: float64
#
# categorical variable: occupation
#  Prof-specialty       0.127146
#  Craft-repair         0.125887
#  Exec-managerial      0.124873
#  Adm-clerical         0.115783
#  Sales                0.112097
#  Other-service        0.101195
#  Machine-op-inspct    0.061485
#  ?                    0.056601
#  Transport-moving     0.049046
#  Handlers-cleaners    0.042075
#  Farming-fishing      0.030527
#  Tech-support         0.028500
#  Protective-serv      0.019932
#  Priv-house-serv      0.004576
#  Armed-Forces         0.000276
# Name: occupation, dtype: float64
#
# categorical variable: race
#  White                 0.854274
#  Black                 0.095943
#  Asian-Pac-Islander    0.031909
#  Amer-Indian-Eskimo    0.009551
#  Other                 0.008323
# Name: race, dtype: float64
#
# categorical variable: marital-status
#  Married-civ-spouse       0.459937
#  Never-married            0.328092
#  Divorced                 0.136452
#  Separated                0.031479
#  Widowed                  0.030497
#  Married-spouse-absent    0.012837
#  Married-AF-spouse        0.000706
# Name: marital-status, dtype: float64
#
# categorical variable: native-country
#  United-States                 0.895857
#  Mexico                        0.019748
#  ?                             0.017905
#  Philippines                   0.006081
#  Germany                       0.004207
#  Canada                        0.003716
#  Puerto-Rico                   0.003501
#  El-Salvador                   0.003255
#  India                         0.003071
#  Cuba                          0.002918
#  England                       0.002764
#  Jamaica                       0.002488
#  South                         0.002457
#  China                         0.002303
#  Italy                         0.002242
#  Dominican-Republic            0.002150
#  Vietnam                       0.002058
#  Guatemala                     0.001966
#  Japan                         0.001904
#  Poland                        0.001843
#  Columbia                      0.001812
#  Taiwan                        0.001566
#  Haiti                         0.001351
#  Iran                          0.001321
#  Portugal                      0.001136
#  Nicaragua                     0.001044
#  Peru                          0.000952
#  Greece                        0.000891
#  France                        0.000891
#  Ecuador                       0.000860
#  Ireland                       0.000737
#  Hong                          0.000614
#  Trinadad&Tobago               0.000584
#  Cambodia                      0.000584
#  Laos                          0.000553
#  Thailand                      0.000553
#  Yugoslavia                    0.000491
#  Outlying-US(Guam-USVI-etc)    0.000430
#  Honduras                      0.000399
#  Hungary                       0.000399
#  Scotland                      0.000369
#  Holand-Netherlands            0.000031
# Name: native-country, dtype: float64
#
# categorical variable: sex
#  Male      0.669205
#  Female    0.330795
# Name: sex, dtype: float64
#
# categorical variable: annual-income
#  <=50K    0.75919
#  >50K     0.24081
# Name: annual-income, dtype: float64
#
# categorical variable: education
#  HS-grad         0.322502
#  Some-college    0.223918
#  Bachelors       0.164461
#  Masters         0.052916
#  Assoc-voc       0.042443
#  11th            0.036086
#  Assoc-acdm      0.032769
#  10th            0.028654
#  7th-8th         0.019840
#  Prof-school     0.017690
#  9th             0.015786
#  12th            0.013298
#  Doctorate       0.012684
#  5th-6th         0.010227
#  1st-4th         0.005160
#  Preschool       0.001566
# Name: education, dtype: float64
# [None, None, None, None, None, None, None, None, None]

# %% [markdown]
# ### 4. Draw bar plots for each categorical variable.

# %%
# [dataset[i].value_counts().plot.bar(title=f'Freq dist of {i}') for i in categorical_variables_cols_list]
for categorical_variables_col in categorical_variables_cols_list:
    dataset[categorical_variables_col].value_counts().plot.bar()
    plt.title(f'Freq dist of {categorical_variables_col}')
    # plt.savefig(f'bar{categorical_variables_col}.png')
    plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### 5. For each continuous variable, draw histograms and distribution plots.

# %% [markdown]
# #### histograms

# %%
# method1
for continuous_variables_col in continuous_variables_cols_list: 
    dataset[continuous_variables_col].hist(figsize= (8, 8), bins= 100)
    plt.title(continuous_variables_col)
    # plt.savefig(f'hist{continuous_variables_col}.png')
    plt.show()

# %%
# method2
dataset.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001818852FE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000018188554C48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000018188580208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000181885B4C08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000181885ED5C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000018188623F88>]],
#       dtype=object)

# %% [markdown]
# #### distribution plots

# %%
fig, ax = plt.subplots(len(continuous_variables_cols_list), figsize=(16, 30))
for idx, continuous_variables_col in enumerate(continuous_variables_cols_list):
    sns.distplot(dataset[continuous_variables_col], hist=True, ax=ax[idx])
    ax[idx].set_title('Freq dist '+ continuous_variables_col, fontsize=20)
    ax[idx].set_xlabel(continuous_variables_col, fontsize=10)
    ax[idx].set_ylabel('Count', fontsize=10)
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### 6. Draw pairwise scatterplots for continuous variables. Explain any discernable patterns?

# %%
# method1
sns.pairplot(dataset[continuous_variables_cols_list])
plt.show()

# %%
# method2
for continuous_variables_col2 in continuous_variables_cols_list:
    for continuous_variables_col1 in continuous_variables_cols_list: 
        plt.scatter(dataset[continuous_variables_col1], dataset[continuous_variables_col2])       
        plt.xlabel(f'{continuous_variables_col1}')
        plt.ylabel(f'{continuous_variables_col2}')
        plt.show()

# %% [markdown]
# * capital-gain和capital-loss呈現L型，因為兩者一至少有一個為0(因兩者有互斥性質)
# * capital-gain當一軸時，中間通常是空掉的
# * 有些的分布情形是佈滿圖，而有些是點大部分接近於兩軸

# %% [markdown]
# ### 7. Draw a heatmap for the correlations among all variables. What do you observe?

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(dataset.corr(), annot=False, center=0.0, cmap='coolwarm'); # cmap="YlGnBu",
#plt.savefig('heatmap.png')
plt.show()

# %% [markdown]
# * correlation是pairwise
# * only continuous variables, no categorical variables
# * 自己和自己的block一定是紅色(因為correlation = 1)
# * fnlwgt和大部分都無相關
# * education-num算是和大部分的其他變數最相關的
# * capital-gain和capital-loss幾乎為0，因為兩者一至少有一個為0(因兩者有互斥性質)
